# %%
import quantstats as qs

# %%
print(qs.__file__)
# Out:
# d:\WORK\Offices\quniq\sentry\quniqstats-main\quantstats\__init__.py

# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('META')
stock
# Out:
# Date
# 2012-05-18         NaN
# 2012-05-21   -0.109861
# 2012-05-22   -0.089039
# 2012-05-23    0.032258
# 2012-05-24    0.032187
#                 ...
# 2022-11-28   -0.023607
# 2022-11-29    0.006251
# 2022-11-30    0.078933
# 2022-12-01    0.019814
# 2022-12-02    0.025324
# Name: Close, Length: 2654, dtype: float64

# %%
# qs.reports.full(stock, "SPY")

# %% [markdown]
# ## Basic Metrics

# %%
# Sharpe Ratio (Value only)

# %%
qs.stats.sharpe(stock)
# Out:
# 0.4795353249788563

# %%
# Max Drawdown% (Value Only)

# %%
qs.stats.max_drawdown(stock)
# Out:
# -0.7673609153644647

# %%
# Volatility%(annualised) (Value Only)

# %%
qs.stats.volatility(stock)
# Out:
# 0.4007593294686849

# %%
# Rolling Volatility

# %%
qs.stats.rolling_volatility(stock, prepare_returns=True)[-30:]
# Out:
# Date
# 2022-10-21    0.573769
# 2022-10-24    0.573210
# 2022-10-25    0.578310
# 2022-10-26    0.581706
# 2022-10-27    0.625947
# 2022-10-28    0.625767
# 2022-10-31    0.625272
# 2022-11-01    0.626333
# 2022-11-02    0.623591
# 2022-11-03    0.617659
# 2022-11-04    0.618428
# 2022-11-07    0.624836
# 2022-11-08    0.624606
# 2022-11-09    0.627057
# 2022-11-10    0.644491
# 2022-11-11    0.642013
# 2022-11-14    0.642149
# 2022-11-15    0.643006
# 2022-11-16    0.640779
# 2022-11-17    0.641015
# 2022-11-18    0.640774
# 2022-11-21    0.640691
# 2022-11-22    0.632799
# 2022-11-23    0.632499
# 2022-11-25    0.629189
# 2022-11-28    0.629059
# 2022-11-29    0.629195
# 2022-11-30    0.639130
# 2022-12-01    0.634780
# 2022-12-02    0.633778
# Name: Close, dtype: float64

# %%
# Rolling Sharpe

# %%
qs.stats.rolling_sharpe(stock, prepare_returns=True)[-30:]
# Out:
# Date
# 2022-10-21   -0.930493
# 2022-10-24   -0.993763
# 2022-10-25   -0.665609
# 2022-10-26   -0.739992
# 2022-10-27   -2.034473
# 2022-10-28   -1.912224
# 2022-10-31   -2.278575
# 2022-11-01   -2.218406
# 2022-11-02   -2.557289
# 2022-11-03   -2.420857
# 2022-11-04   -2.279435
# 2022-11-07   -1.928238
# 2022-11-08   -1.960726
# 2022-11-09   -1.643971
# 2022-11-10   -1.322544
# 2022-11-11   -1.415841
# 2022-11-14   -1.404740
# 2022-11-15   -1.365101
# 2022-11-16   -1.312585
# 2022-11-17   -1.345732
# 2022-11-18   -1.366147
# 2022-11-21   -1.470722
# 2022-11-22   -1.202819
# 2022-11-23   -1.225169
# 2022-11-25   -1.389995
# 2022-11-28   -1.523404
# 2022-11-29   -1.478932
# 2022-11-30   -1.128141
# 2022-12-01   -1.244141
# 2022-12-02   -1.037975
# Name: Close, dtype: float64

# %%
# Daily Returns

# %%
qs.plots.daily_returns(stock, data=True)
# Out:
# Date
# 2012-05-18     0.000000
# 2012-05-21   -10.986139
# 2012-05-22    -8.903905
# 2012-05-23     3.225806
# 2012-05-24     3.218746
#                 ...
# 2022-11-28    -2.360654
# 2022-11-29     0.625115
# 2022-11-30     7.893294
# 2022-12-01     1.981375
# 2022-12-02     2.532377
# Name: Close, Length: 2654, dtype: float64

# %%
# Top 5 Drawdown periods

# %%
top_five_dd = qs.plots.drawdowns_periods(stock, periods=5, data=True)
top_five_dd
# Out:
#           start      valley         end  days  max drawdown  99% max drawdown
# 87   2018-07-26  2018-12-24  2020-01-09   532    -42.960921        -39.434485
# 113  2021-09-08  2022-11-03  2022-12-02   450    -76.736092        -75.090272
# 0    2012-05-21  2012-09-04  2013-08-05   441    -53.622810        -50.405443
# 100  2020-08-27  2021-01-14  2021-04-05   221    -19.173441        -18.061268
# 21   2014-03-11  2014-04-28  2014-07-24   135    -22.060252        -21.213382

# %%
# Monthly Returns

# %%
qs.plots.monthly_returns(stock)
# Out:
#             JAN        FEB        MAR        APR        MAY        JUN  \
# 2012   0.000000   0.000000   0.000000   0.000000 -22.573893   5.067568
# 2013  16.378657 -12.040025  -6.128441   8.561378 -12.315448   2.176586
# 2014  14.492219   9.413456 -12.007008  -0.763617   5.888258   6.303320
# 2015  -2.704426   4.031086   4.115487  -4.196065   0.533205   8.309122
# 2016   7.213831  -4.714376   6.715302   3.049959   1.046093  -3.812809
# 2017  13.272494   4.005514   4.803018   5.772613   0.805329  -0.316923
# 2018   5.910684  -4.585581 -10.391439   7.641284  11.499999   1.324439
# 2019  27.156921  -3.143563   3.245590  16.023751  -8.236811   8.750774
# 2020  -1.627282  -4.675352 -13.337142  22.727820   9.955541   0.879653
# 2021  -5.429059  -0.274839  14.327305  10.372454   1.122808   5.773729
# 2022  -6.864872 -32.634236   5.368906  -9.844396  -3.406994 -16.726916
#
#             JUL        AUG        SEP        OCT        NOV        DEC
# ...

# %%
# Time Series Returns (MTD, 3M, 6M, YTD, 1y, 2y, 3y, 5y, 10y, Total) All Values only.

# %%
time_series_returns = qs.reports.metrics(mode="full", returns=stock).iloc[42:50].values
time_series_returns
# Out:
# array([['-34.54%'],
#        ['-63.29%'],
#        ['-60.24%'],
#        ['-14.8%'],
#        ['-6.75%'],
#        ['16.4%'],
#        ['11.76%'],
#        ['']], dtype=object)

# %%
# Best day (Value only)

# %%
best_day = qs.reports.metrics(mode="full", returns=stock).iloc[52].values[0]
best_day
# Out:
# '47.91%'

# %%
# Best year (Value only)

# %%
best_year = qs.reports.metrics(mode="full", returns=stock).iloc[53].values[0]
best_year
# Out:
# '-32.63%'

# %% [markdown]
# ## Advanced Metrics

# %%
# Total/Cumulative Return vs Benchmark(Nifty) (Graph)

# %%
cumulative_returns = qs.plots.returns(stock, "SPY")
cumulative_returns
# Out:
# [Date
#  2012-05-18      0.000000
#  2012-05-21    -10.986139
#  2012-05-22    -18.911848
#  2012-05-23    -16.296102
#  2012-05-24    -13.601885
#                   ...
#  2022-11-28    184.540937
#  2022-11-29    186.319645
#  2022-11-30    208.919696
#  2022-12-01    215.040554
#  2022-12-02    223.018570
#  Name: Close, Length: 2654, dtype: float64,
#  Date
#  2012-05-18      0.000000
#  2012-05-21      1.718831
#  2012-05-22      1.896087
#  2012-05-23      1.950063
#  2012-05-24      2.150445
#                   ...
#  2022-11-28    272.220398
#  2022-11-29    271.581094
#  2022-11-30    283.286120
#  2022-12-01    283.004082
#  2022-12-02    282.562204
#  Name: Close, Length: 2654, dtype: float64]

# %%
# EoY Returns vs Benchmark (Graph)

# %%
eoy_returns = qs.plots.yearly_returns(stock, "SPY")
eoy_returns
# Out:
# [Date
#  2012-12-31    -30.368817
#  2013-12-31    105.296769
#  2014-12-31     42.763027
#  2015-12-31     34.145101
#  2016-12-31      9.927383
#  2017-12-31     53.376794
#  2018-12-31    -25.711214
#  2019-12-31     56.571825
#  2020-12-31     33.086482
#  2021-12-31     23.132963
#  2022-12-31    -63.285270
#  Freq: A-DEC, Name: Close, dtype: float64,
#  Date
#  2012-12-31    11.710127
#  2013-12-31    32.307779
#  2014-12-31    13.463793
#  2015-12-31     1.234303
#  2016-12-31    11.997881
#  2017-12-31    21.705410
#  2018-12-31    -4.569005
#  2019-12-31    31.223851
#  2020-12-31    18.331641
#  2021-12-31    28.728760
#  2022-12-31   -13.335591
#  Freq: A-DEC, Name: Close, dtype: float64]

# %%
# Drawdown (Underwater plot graph)

# %%
underwater = qs.plots.drawdown(stock, "SPY")
underwater
# Out:
# Date
# 2012-05-18     0.000000
# 2012-05-21   -10.986139
# 2012-05-22   -18.911848
# 2012-05-23   -16.296102
# 2012-05-24   -13.601885
#                 ...
# 2022-11-28   -71.536972
# 2022-11-29   -71.359045
# 2022-11-30   -69.098330
# 2022-12-01   -68.486052
# 2022-12-02   -67.688000
# Name: Close, Length: 2654, dtype: float64

# %%
# Monthly Return Distribution (Graph)
# Histogram Plot

# %%
monthly_ret_dist = qs.plots.histogram(stock, data=True)
monthly_ret_dist
# Out:
# Date
# 2012-05-31   -22.573893
# 2012-06-30     5.067568
# 2012-07-31   -30.192930
# 2012-08-31   -16.812528
# 2012-09-30    19.933558
#                 ...
# 2022-08-31     2.407282
# 2022-09-30   -16.724975
# 2022-10-31   -31.338437
# 2022-11-30    26.771140
# 2022-12-31     4.563928
# Freq: M, Name: Close, Length: 128, dtype: float64

# %%
# Rolling Volatility (6-months) (Graph)

# %%
rolling_vol_xmonth = qs.plots.rolling_volatility(stock, "SPY", period=126, period_label="6-Months", data=True)
rolling_vol_xmonth
# Out:
#             Benchmark  Strategy
# Date
# 2012-11-16   0.138190  0.678709
# 2012-11-19   0.140973  0.679559
# 2012-11-20   0.138995  0.662469
# 2012-11-21   0.138997  0.655326
# 2012-11-23   0.140222  0.653812
# ...               ...       ...
# 2022-11-28   0.248536  0.629059
# 2022-11-29   0.248426  0.629195
# 2022-11-30   0.252159  0.639130
# 2022-12-01   0.250720  0.634780
# 2022-12-02   0.249633  0.633778
#
# [2529 rows x 2 columns]

# %%
# Rolling Sharpe (6-months) (Graph)

# %%
rolling_sharpe_xmonth = qs.plots.rolling_sharpe(stock, "SPY", period=126, period_label="6-Months", data=True)
rolling_sharpe_xmonth
# Out:
#             Benchmark  Strategy
# Date
# 2012-11-16   0.059334 -0.068649
# 2012-11-19   0.076250 -0.073600
# 2012-11-20   0.062147 -0.053111
# 2012-11-21   0.062259 -0.026419
# 2012-11-23   0.073482 -0.035231
# ...               ...       ...
# 2022-11-28  -0.012167 -0.095965
# 2022-11-29  -0.010197 -0.093164
# 2022-11-30   0.009734 -0.071066
":11378054.2435771506,\"1644451200000\":11441433.8016543146,\"1644537600000\":11275751.744215643,\"1644796800000\":10974888.3956555612,\"1644883200000\":11228354.1187655739,\"1644969600000\":11204532.8285349384,\"1645056000000\":11173221.3378101122,\"1645142400000\":11134283.5101803765,\"1645401600000\":11095932.1157159582,\"1645488000000\":11022060.680453768,\"1645574400000\":11017656.2953825798,\"1645660800000\":10511200.613834735,\"1645747200000\":10818703.1292291936,\"1646006400000\":10913556.3881722055,\"1646179200000\":10830075.0402650647,\"1646265600000\":10805024.1332044769,\"1646352000000\":10698707.5150067322,\"1646611200000\":10527629.4970853366,\"1646697600000\":10681427.1758093145,\"1646784000000\":10825051.5343777109,\"1646870400000\":10940875.7963184267,\"1646956800000\":11031367.7213231847,\"1647216000000\":11093076.2068657354,\"1647302400000\":11000816.791014161,\"1647388800000\":11167639.3919316232,\"1647475200000\":11257686.5650794972,\"1647820800000\":11143644.7997121867,\"1647907200000\":11169634.6569655016,\"1647993600000\":11152271.5087058432}"

# %%
# For Value Section of Portfolio
value = values.replace("\ ","")
res_dict = {}
# value = value.replace("0000","0")
value = value.replace(" ","_")
value = json.loads(value)
res_dict['value']=value

dicts = res_dict['value']

# %%
df = pd.DataFrame(res_dict['value'], index=[0]).T
df.reset_index(inplace=True)

# %%
df = df.rename(columns={'index': 'date', 0: 'value'})

# %%
df["date"] = df["date"].apply(lambda d: pd.Timestamp(int(d),unit='ms').strftime('%Y-%m-%d'))

# %%
df.head(2)
# Out:
#          date         value
# 0  2021-06-22  1.000000e+07
# 1  2021-06-23  9.980073e+06

# %%
key1 = df['date'].to_list()
values = df['value'].to_list()

new_dict = {key1[i]: int(values[i]) for i in range(len(key1))}

stock_n = pd.Series(new_dict)
# stock_n

# %%
stock_n.index = pd.to_datetime(stock_n.index)
stock_n.index
# Out:
# DatetimeIndex(['2021-06-22', '2021-06-23', '2021-06-24', '2021-06-25',
#                '2021-06-28', '2021-06-29', '2021-06-30', '2021-07-01',
#                '2021-07-02', '2021-07-05',
#                ...
#                '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-14',
#                '2022-03-15', '2022-03-16', '2022-03-17', '2022-03-21',
#                '2022-03-22', '2022-03-23'],
#               dtype='datetime64[ns]', length=188, freq=None)

# %%
nifty = qs.utils.download_returns('^NSEI')
nifty = nifty[(nifty.index > '2021-06-22') & (nifty.index <= '2022-03-23')]

# %%
# nifty

# %%
# qs.plots.drawdown(stock_n)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

qs.reports.metrics(stock_n, mode="full")
# Out:
#                               Strategy
# Start Period                2021-06-22
# End Period                  2022-03-23
#
# Cumulative Return               11.52%
# CAGR﹪                           15.64%
#
# Sharpe                            1.06
# Smart Sharpe                      1.04
# Sortino                           1.45
# Smart Sortino                     1.42
# Sortino/√2                        1.02
# Smart Sortino/√2                   1.0
# Omega                             1.19
#
# Max Drawdown                   -11.64%
# Longest DD Days                    155
# Volatility (ann.)                14.9%
# Calmar                            1.34
# Skew                             -0.81
# Kurtosis                          3.02
#
# Expected Daily %                 0.06%
# Expected Monthly %                1.1%
# Expected Yearly %                 5.6%
# Kelly Criterion                  8.97%
# Risk of Ruin                      0.0%
# Daily Value-at-Risk             -1.48%
# ...

# %%
qs.stats.volatility(nifty)
# Out:
# 0.16271709664093303
